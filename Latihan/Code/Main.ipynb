# %%
# %matplotlib widget


import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26912/673738769.py in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2
#       3
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2349                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2350             with self.builtin_trap:
# -> 2351                 result = fn(*args, **kwargs)
#    2352             return result
#    2353
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3531                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3532
# -> 3533         pt.activate_matplotlib(backend)
#    3534         configure_inline_support(self, backend)
#    3535
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\IPython\core\pylabtools.py in activate_matplotlib(backend)
#     357     from matplotlib import pyplot as plt
#     358
# --> 359     plt.switch_backend(backend)
#     360
#     361     plt.show._needmain = False
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\matplotlib\pyplot.py in switch_backend(newbackend)
#     275     backend_name = cbook._backend_module_name(newbackend)
#     276
# --> 277     class backend_mod(matplotlib.backend_bases._Backend):
#     278         locals().update(vars(importlib.import_module(backend_name)))
#     279
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\site-packages\matplotlib\pyplot.py in backend_mod()
#     276
#     277     class backend_mod(matplotlib.backend_bases._Backend):
# --> 278         locals().update(vars(importlib.import_module(backend_name)))
#     279
#     280     required_framework = _get_required_interactive_framework(backend_mod)
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\Users\ACE COMPUTER STORE\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'ipympl'

# %% [markdown]
# # Generate Data

# %%
jumlah_data = 100

y = np.array([i * 0.1 + np.random.randn() for i in range(jumlah_data)])
x = np.array([i * 0.1 for i in range(jumlah_data)])

# %% [markdown]
# ### 1. Plot Data

# %%
plt.scatter(x, y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 2. Fungsi Linear

# %%
def ucup_Linear(x, gradient):
    y = gradient * x
    return y

# %% [markdown]
# Menghitung Linear Awal

# %%
x_prediksi = np.array([0, 10])
m_awal = 5
y_prediksi = ucup_Linear(x_prediksi, m_awal)

# %%
# plt.scatter(x, y)
# plt.plot(x_prediksi, y_prediksi, "Red")
# plt.axis([0,10,0,10])
# plt.show()

# %% [markdown]
# Menghitung Prediksi

# %%
m_preddiksi = m_awal
m_list_prediksi = []
y_list_prediksi = []
x_list_prediksi = []
Learning_rate = 0.1
for i in range(1, jumlah_data):
    y_prediksi = ucup_Linear(x[i], m_preddiksi)
    y_aktual = y[i]  

    error = y_aktual - y_prediksi
    delta_m = Learning_rate*error/x[i]
    m_preddiksi = m_preddiksi + delta_m

    m_list_prediksi.append(m_preddiksi)
    y_list_prediksi.append(ucup_Linear(np.array([0,10]), m_preddiksi))
    x_list_prediksi.append(np.array([0,10]))

# %% [markdown]
# Visualisasi Prediksi

# %%
fig = plt.figure(figsize = (4,4))
Line, = plt.plot([], [], "Red")

def animate(frame_num):
    x = [0, x_list_prediksi[frame_num]]
    y = [0, y_list_prediksi[frame_num]]
    # Line.set_data((x_list_prediksi[frame_num], y_list_prediksi[frame_num]))
    Line.set_data((x,y))
    return Line



anime = FuncAnimation(fig, animate, frames = 100, interval = 100, repeat = False) 
plt.scatter(x,y)
plt.axis([0,10,0,10])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
